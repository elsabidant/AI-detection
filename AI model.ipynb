# %% [markdown]
# # AI detection model

# %% [markdown]
# ## Library import

# %%
import pandas as pd
import spacy
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import re

from collections import Counter
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
import copy

from transformers import AutoTokenizer, AutoModelForSequenceClassification

from statsmodels.stats.contingency_tables import mcnemar

# %% [markdown]
# ## Data import

# %% [markdown]
# 0 - Human written paragraph
#
# 1 - AI generated paragraph

# %%
df_human = pd.read_csv("victorian_texts_human.csv")
df_IA = pd.read_csv("IA_texts.csv", sep = ";")

# %%
# Renaming columns for consistency
df_human = df_human.rename(columns={"texte": "text", "titre": "title", "auteur": "author"})
df_IA = df_IA.rename(columns={"Text": "text"})

# Adding a label column to both dataframes
df_human["label"] = 0  # Human written
df_IA["label"] = 1     # AI generated

# Combining the dataframes
df = pd.concat([df_human, df_IA], ignore_index=True)
df
# Out:
#                                                   text  \
# 0    “The twinkling of the _what?_” said the King. ...
# 1    The first thing she heard was a general chorus...
# 2    “Nobody asked _your_ opinion,” said Alice. “Wh...
# 3    The executioner’s argument was, that you could...
# 4    “I haven’t the least idea what you’re talking ...
# ..                                                 ...
# 995  Heathcliff knelt in the mud, his hands pressed...
# 996  Young Cathy Linton’s laughter rang through the...
# 997  Hareton Earnshaw’s hands shook as he fastened ...
# 998  Nelly found Heathcliff in the old barn, his fa...
# 999  The children of Wuthering Heights and Thrushcr...
#
#                                 title         author  label
# 0    Alice's Adventures in Wonderland  Lewis Carroll      0
# 1    Alice's Adventures in Wonderland  Lewis Carroll      0
# 2    Alice's Adventures in Wonderland  Lewis Carroll      0
# 3    Alice's Adventures in Wonderland  Lewis Carroll      0
# 4    Alice's Adventures in Wonderland  Lewis Carroll      0
# ..                                ...            ...    ...
# 995                 Wuthering Heights      MistralAI      1
# 996                 Wuthering Heights      MistralAI      1
# 997                 Wuthering Heights      MistralAI      1
# 998                 Wuthering Heights      MistralAI      1
# 999                 Wuthering Heights      MistralAI      1
#
# [1000 rows x 4 columns]

# %% [markdown]
# ## Embeddings

# %%
# Cleaning text data
def clean_text(text):
    text = text.lower()
    text = re.sub(r"[^a-z\s]", "", text)
    return text.split()

# %%
def preprocess_embs(name = 'glove-wiki-gigaword-100'):
    import gensim.downloader as api

    # Load pretrained embedding model
    model = api.load(name)

    # Extract vocabulary
    vocab = model.key_to_index

    # Extract embedding vectors
    embedding_matrix = model.vectors

    return vocab, embedding_matrix

# %%
def text_to_embedding(text, vocab, emb_matrix):

    # Clean and tokenize text
    words = clean_text(text)
    
    vectors = []

    # Retrieve embeddings for words in vocabulary
    for w in words:
        if w in vocab:
            vectors.append(emb_matrix[vocab[w]])
    
    if len(vectors) == 0:
        return torch.zeros(emb_matrix.shape[1])
    
    return torch.tensor(vectors).mean(dim=0)

# %%
# Convert the dataset into embeddings and labels
def preprocess_data(df, vocab, emb_matrix):
    X = []
    y = []

    for _, row in df.iterrows():
        emb = text_to_embedding(row["text"], vocab, emb_matrix)
        X.append(emb)
        y.append(row["label"])

    return torch.stack(X), torch.tensor(y)

# %%
vocab, emb_matrix = preprocess_embs()
X, y = preprocess_data(df, vocab, emb_matrix)

# %% [markdown]
# ## Linguistic features

# %% [markdown]
# ### POS distribution

# %%
# Load SpaCy English model for POS tagging
nlp = spacy.load("en_core_web_sm")

def pos_features(text):
    doc = nlp(text)
    total = len(doc)
    
    counts = {
        "NOUN": 0,
        "DET": 0,
        "ADP": 0,
        "ADJ": 0,
        "ADV": 0
    }
    
    for token in doc:
        if token.pos_ in counts:
            counts[token.pos_] += 1
    
    return [
        counts["NOUN"]/total,
        counts["DET"]/total,
        counts["ADP"]/total,
        counts["ADJ"]/total,
        counts["ADV"]/total
    ]

pos_matrix = np.array([pos_features(t) for t in tqdm(df["text"])])
# Out:
# 100%|██████████| 1000/1000 [00:31<00:00, 31.25it/s]

# %%
# Add POS features to the DataFrame
df["noun_ratio"] = pos_matrix[:,0]
df["det_ratio"] = pos_matrix[:,1]
df["adp_ratio"] = pos_matrix[:,2]
df["adj_ratio"] = pos_matrix[:,3]
df["adv_ratio"] = pos_matrix[:,4]

# %% [markdown]
# ### Type/token ratio : linguistic diversity

# %%
# Compute lexical diversity (unique tokens / total tokens)
def lexical_diversity(text):
    tokens = text.split()
    if len(tokens) == 0:
        return 0
    return len(set(tokens)) / len(tokens)

df["lexical_diversity"] = [lexical_diversity(t) for t in tqdm(df["text"])]
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 43100.28it/s]

# %% [markdown]
# ### n-gram diversity

# %%
# Compute n-gram diversity (ratio of unique n-grams to total n-grams)
def ngram_diversity(text, n=2):
    tokens = text.split()
    
    if len(tokens) < n:
        return 0
    
    # Generate n-grams
    ngrams = list(zip(*[tokens[i:] for i in range(n)]))
    
    total = len(ngrams)
    unique = len(set(ngrams))
    
    return unique / total

# Compute bigram and trigram diversity
df["bigram_div"] = [ngram_diversity(t, 2) for t in tqdm(df["text"])]
df["trigram_div"] = [ngram_diversity(t, 3) for t in tqdm(df["text"])]
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 24800.17it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 28730.08it/s]

# %% [markdown]
# ### Mean and standard deviation of sentences' lenght

# %%
# Compute sentence length' mean and standard deviation 

def sentence_length_features(text):

    sentences = re.split(r'[.!?]+', text)
    sentences = [s.strip() for s in sentences if len(s.strip()) > 0]
    
    if len(sentences) == 0:
        return 0, 0
    
    # Compute sentence lengths
    lengths = [len(s.split()) for s in sentences]
    return np.mean(lengths), np.std(lengths)

means = []
stds = []

# Compute sentence length features for all texts
for t in tqdm(df["text"], desc="Sentence length features"):
    mean_len, std_len = sentence_length_features(t)
    means.append(mean_len)
    stds.append(std_len)

df["sentence_length_mean"] = means
df["sentence_length_std"] = stds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 19
#      16 stds = []
#      18 # Compute sentence length features for all texts
# ---> 19 for t in tqdm(df["text"], desc="Sentence length features"):
#      20     mean_len, std_len = sentence_length_features(t)
#      21     means.append(mean_len)
#
# NameError: name 'tqdm' is not defined

# %% [markdown]
# ### Saving data

# %%
df.to_csv("dataset_AI_human_full.csv", index=False)

# %% [markdown]
# ## Train, dev, test splits

# %%
# Train, dev and test split 
X = X

# Train and temp split (80/20)
indices = np.arange(len(df))
X_train, X_temp, y_train, y_temp, idx_train, idx_temp = train_test_split(
    X,
    y,
    indices,
    test_size=0.2,
    random_state=42,
    stratify=y
)

# Dev and test split (10/10)
X_dev, X_test, y_dev, y_test, idx_dev, idx_test = train_test_split(
    X_temp,
    y_temp,
    idx_temp,
    test_size=0.5,
    random_state=42,
    stratify=y_temp
)

# %%
features = [
    "noun_ratio", "det_ratio", "adp_ratio",
    "adj_ratio", "adv_ratio",
    "lexical_diversity",
    "bigram_div", "trigram_div",
    "sentence_length_mean", "sentence_length_std"
]

# Definition of X and y for linguistic features
X_ling = df[features].copy()
y_ling = df["label"].copy()

# Convert embeddings tensor to dataframe
X_embed = pd.DataFrame(X.numpy())
X_embed.columns = X_embed.columns.astype(str)

# Combine embeddings and linguistic features
X_nn_ling = pd.concat(
    [X_embed, X_ling],
    axis=1
)

# Train, dev and test split for linguistic features
X_train_ling, X_temp_ling, y_train_ling, y_temp_ling = train_test_split(
    X_ling, y_ling,
    test_size=0.2,
    random_state=42,
    stratify=y_ling
)

X_dev_ling, X_test_ling, y_dev_ling, y_test_ling = train_test_split(
    X_temp_ling, y_temp_ling,
    test_size=0.5,
    random_state=42,
    stratify=y_temp_ling
)

# Scaling features
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train_ling)
X_dev_scaled = scaler.transform(X_dev_ling)
X_test_scaled = scaler.transform(X_test_ling)

# %% [markdown]
# ## Functions to compute metrics

# %%
# Function for the logistic regression model evaluation
def evaluate_sklearn_model(model, X_test, y_test):

    # Predict labels
    y_pred = model.predict(X_test)

    # Compute metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    return {
    "Accuracy": float(accuracy),
    "Precision": float(precision),
    "Recall": float(recall),
    "F1-score": float(f1)
    }

# %%
# Function for the NN model evaluation

def evaluate_model(model, X_test, y_test):

    model.eval()

    with torch.no_grad():
        # Predict probabilities
        y_pred_probs = model(X_test).squeeze()
        # Convert probabilities to binary predictions
        y_pred = (y_pred_probs > 0.5).float()

    # Convert tensors to numpy arrays
    y_true = y_test.cpu().numpy()
    y_pred = y_pred.cpu().numpy()

    # Compute metrics
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)

    return {
    "Accuracy": float(accuracy),
    "Precision": float(precision),
    "Recall": float(recall),
    "F1-score": float(f1)
    }

# %% [markdown]
# ## Model

# %% [markdown]
# ### Logistic regression

# %%
best_acc = 0
best_model = None

for C in [0.01, 0.1, 1, 10]:
    # Training model with current C value
    LR_model = LogisticRegression(C=C, max_iter=1000)
    LR_model.fit(X_train, y_train)

    # Evaluating on dev set
    preds = LR_model.predict(X_dev)
    acc = accuracy_score(y_dev, preds)

    # Updating best model if current one is better
    if acc > best_acc:
        best_acc = acc
        best_model = LR_model

# %%
pred_logreg = best_model.predict(X_test)
print(confusion_matrix(y_test, pred_logreg))
# Out:
# [[47  3]
#  [ 3 47]]

# %%
results_logreg = evaluate_sklearn_model(
    best_model,
    X_test,
    y_test
)

print(results_logreg)
# Out:
# {'Accuracy': 0.94, 'Precision': 0.94, 'Recall': 0.94, 'F1-score': 0.94}

# %%
# Diagnosis of logistic regression 
y_train_pred = best_model.predict(X_train)
accuracy_score(y_train, y_train_pred)
# Out:
# 0.9475

# %% [markdown]
# ### Logistic regression with linguistic features

# %%
# Logistic regression with linguistic features

best_acc = 0
best_model_ling = None

for C in [0.01, 0.1, 1, 10]:
    LR2_model = LogisticRegression(C=C, max_iter=1000)
    LR2_model.fit(X_train_scaled, y_train_ling)

    preds = LR2_model.predict(X_dev_scaled)
    acc = accuracy_score(y_dev_ling, preds)

    if acc > best_acc:
        best_acc = acc
        best_model_ling = LR2_model

# %%
pred_logreg_ling = best_model_ling.predict(X_test_scaled)
print(confusion_matrix(y_test_ling, pred_logreg_ling))
# Out:
# [[46  4]
#  [ 2 48]]

# %%
results_logreg_ling = evaluate_sklearn_model(
    best_model_ling,
    X_test_scaled,
    y_test_ling
)

print(results_logreg_ling)
# Out:
# {'Accuracy': 0.94, 'Precision': 0.9230769230769231, 'Recall': 0.96, 'F1-score': 0.9411764705882353}

# %%
# Diagnosis of logistic regression with linguistic features
y_train_pred = best_model_ling.predict(X_train_scaled)
accuracy_score(y_train_ling, y_train_pred)
# Out:
# 0.91125

# %%
coef = best_model_ling.coef_[0]
importance_df = pd.DataFrame({
    "feature": features,
    "importance": coef
})

# Sorting by importance
importance_df = importance_df.sort_values(by="importance")

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Labels propres
feature_names = {
    "noun_ratio": "Noun ratio",
    "det_ratio": "Determiner ratio",
    "adp_ratio": "Preposition ratio",
    "adj_ratio": "Adjective ratio",
    "adv_ratio": "Adverb ratio",
    "lexical_diversity": "Lexical diversity",
    "bigram_div": "Bigram diversity",
    "trigram_div": "Trigram diversity",
    "sentence_length_mean": "Mean sentence length",
    "sentence_length_std": "Sentence length variability"
}

coef = pd.Series(best_model_ling.coef_[0], index=features).sort_values(key=abs)

labels = [feature_names[f] for f in coef.index]
values = coef.values

plt.figure(figsize=(6,4))

# lignes
plt.hlines(y=labels, xmin=0, xmax=values, color="#444444", linewidth=2)

# points (jaune comme ton poster)
plt.scatter(values, labels, color="#F4B400", edgecolors="black", zorder=3)

# ligne centrale
plt.axvline(0, linestyle='--', color='black', linewidth=1)

plt.title("Linguistic Feature Impact", fontsize=12, weight='bold')
plt.xlabel("Impact on AI prediction")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Neural Network

# %%
class IAClassification(nn.Module):
    def __init__(self,  input_size, output_size, n_layers, hidden_size, dropout):
        super().__init__()
 
        layers = []
        # Setting up the input layer 
        layers.append(nn.Linear(input_size, hidden_size))
        layers.append(nn.ReLU())
        layers.append(nn.Dropout(p=dropout))

        # Setting up the hidden layers
        for _ in range(n_layers - 1):
            layers.append(nn.Linear(hidden_size, hidden_size))
            layers.append(nn.ReLU())
            layers.append(nn.Dropout(p=dropout))

        # Setting up the output layer for binary classification
        layers.append(nn.Linear(hidden_size, output_size))
        layers.append(nn.Sigmoid()) 

        self.model = nn.Sequential(*layers)
    
    def forward(self, x):
        return self.model(x).squeeze(-1)

# %%
def train(X_train, y_train, X_dev, y_dev, X_test, y_test,
          num_epochs, learning_rate, hidden_size, n_layers, dropout):

    print('Initialising model, optimizer, and loss function')
    input_size = X_train.shape[1]
    output_size = 1
    model = IAClassification(input_size, output_size, n_layers, hidden_size, dropout)
    optimizer = optim.Adam(model.parameters(),
                           lr=learning_rate)
    criterion = nn.BCELoss()

    best_dev_acc = 0
    stable_counter = 0
    min_loss = torch.inf

    print('Starting training...')
    dataset = TensorDataset(X_train, y_train)
    loader = DataLoader(dataset, batch_size=32, shuffle=True)

    for epoch in range(num_epochs):

        # Train 
        model.train()
        for x_batch, y_batch in loader:
            
            # Forward pass (calls the model's forward func)
            y_hat = model(x_batch)
            # Compute loss
            loss = criterion(y_hat, y_batch.float())

            # Backward pass
            optimizer.zero_grad()  # Clear prev gradients
            loss.backward()  # Compute new gradients
            optimizer.step()  # Update model parameters

        # Dev
        model.eval()
        with torch.no_grad():
            dev_outputs = model(X_dev).squeeze()
            dev_loss = criterion(dev_outputs, y_dev.float())
            dev_preds = (dev_outputs > 0.5).float()
            dev_acc = (
                (dev_preds == y_dev)
                .float()
                .mean()
                .item()
            )

        print(
        f"Epoch {epoch+1}/{num_epochs} | "
        f"Train loss: {loss.item():.4f} | "
        f"Dev acc: {dev_acc:.4f}"
        )

        # Early stopping check 
        if dev_loss < min_loss:
            min_loss = dev_loss
            best_dev_acc = dev_acc
            best_model_state = model.state_dict()
            stable_counter = 0
        
        else : 
            stable_counter += 1
            if stable_counter >= 5:
                print(f"Early stopping at epoch {epoch+1}")
                break


    model.load_state_dict(best_model_state)

    return model, best_dev_acc

# %%
# Hyperparameters to test
param_grid = {
    "learning_rate": [1e-3, 5e-4],
    "hidden_size": [64, 128],
    "n_layers": [2, 4],
    "dropout": [0.1, 0.3]
}

best_model = None
best_params = None
best_dev_acc = 0

# Iterate through all hyperparameter combinations
for lr in param_grid["learning_rate"]:
    for hs in param_grid["hidden_size"]:
        for nl in param_grid["n_layers"]:
            for dr in param_grid["dropout"]:

                print("\nTesting configuration:")
                print(
                    f"lr={lr}, "
                    f"hidden={hs}, "
                    f"layers={nl}, "
                    f"dropout={dr}"
                )

                model, dev_acc = train(
                    X_train,
                    y_train,
                    X_dev,
                    y_dev,
                    X_test,
                    y_test,
                    num_epochs=30,
                    learning_rate=lr,
                    hidden_size=hs,
                    n_layers=nl,
                    dropout=dr
                )

                print(f"Dev accuracy: {dev_acc:.4f}")

                # Keep the model with the best dev accuracy
                if dev_acc > best_dev_acc:
                    best_dev_acc = dev_acc
                    best_model = model
                    best_params = {
                        "learning_rate": lr,
                        "hidden_size": hs,
                        "n_layers": nl,
                        "dropout": dr
                    }
# Out:
# Testing configuration:
# lr=0.001, hidden=64, layers=2, dropout=0.1
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.6775 | Dev acc: 0.7300
# Epoch 2/30 | Train loss: 0.6665 | Dev acc: 0.7200
# Epoch 3/30 | Train loss: 0.6000 | Dev acc: 0.7500
# Epoch 4/30 | Train loss: 0.5084 | Dev acc: 0.7500
# Epoch 5/30 | Train loss: 0.5486 | Dev acc: 0.7700
# Epoch 6/30 | Train loss: 0.4221 | Dev acc: 0.8200
# Epoch 7/30 | Train loss: 0.4570 | Dev acc: 0.8200
# Epoch 8/30 | Train loss: 0.3043 | Dev acc: 0.8300
# Epoch 9/30 | Train loss: 0.2369 | Dev acc: 0.8500
# Epoch 10/30 | Train loss: 0.1736 | Dev acc: 0.8400
# Epoch 11/30 | Train loss: 0.2969 | Dev acc: 0.8600
# Epoch 12/30 | Train loss: 0.3116 | Dev acc: 0.8400
# Epoch 13/30 | Train loss: 0.2009 | Dev acc: 0.8700
# Epoch 14/30 | Train loss: 0.1810 | Dev acc: 0.8700
# Epoch 15/30 | Train loss: 0.2257 | Dev acc: 0.8600
# Epoch 16/30 | Train loss: 0.2755 | Dev acc: 0.8700
# Epoch 17/30 | Train loss: 0.1507 | Dev acc: 0.8900
# Epoch 18/30 | Train loss: 0.3674 | Dev acc: 0.8800
# Epoch 19/30 | Train loss: 0.3520 | Dev acc: 0.8800
# Epoch 20/30 | Train loss: 0.2328 | Dev acc: 0.9000
# Epoch 21/30 | Train loss: 0.3868 | Dev acc: 0.8800
# Epoch 22/30 | Train loss: 0.1499 | Dev acc: 0.8800
# Epoch 23/30 | Train loss: 0.2756 | Dev acc: 0.9000
# Epoch 24/30 | Train loss: 0.3287 | Dev acc: 0.9100
# Epoch 25/30 | Train loss: 0.1067 | Dev acc: 0.9200
# Epoch 26/30 | Train loss: 0.2212 | Dev acc: 0.8900
# Epoch 27/30 | Train loss: 0.2324 | Dev acc: 0.9000
# Epoch 28/30 | Train loss: 0.2512 | Dev acc: 0.9100
# Epoch 29/30 | Train loss: 0.1789 | Dev acc: 0.9300
# Epoch 30/30 | Train loss: 0.2261 | Dev acc: 0.9200
# Dev accuracy: 0.9200
#
# Testing configuration:
# lr=0.001, hidden=64, layers=2, dropout=0.3
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.6802 | Dev acc: 0.5500
# Epoch 2/30 | Train loss: 0.6555 | Dev acc: 0.7300
# Epoch 3/30 | Train loss: 0.6876 | Dev acc: 0.7000
# Epoch 4/30 | Train loss: 0.6218 | Dev acc: 0.7500
# Epoch 5/30 | Train loss: 0.5883 | Dev acc: 0.7100
# Epoch 6/30 | Train loss: 0.6353 | Dev acc: 0.7600
# Epoch 7/30 | Train loss: 0.4484 | Dev acc: 0.8000
# Epoch 8/30 | Train loss: 0.4509 | Dev acc: 0.8300
# Epoch 9/30 | Train loss: 0.4259 | Dev acc: 0.8400
# Epoch 10/30 | Train loss: 0.3246 | Dev acc: 0.8300
# Epoch 11/30 | Train loss: 0.2676 | Dev acc: 0.8300
# Epoch 12/30 | Train loss: 0.2971 | Dev acc: 0.8600
# Epoch 13/30 | Train loss: 0.3920 | Dev acc: 0.8500
# Epoch 14/30 | Train loss: 0.2621 | Dev acc: 0.8500
# Epoch 15/30 | Train loss: 0.3369 | Dev acc: 0.8500
# Epoch 16/30 | Train loss: 0.3055 | Dev acc: 0.8600
# Epoch 17/30 | Train loss: 0.2817 | Dev acc: 0.8500
# Epoch 18/30 | Train loss: 0.3220 | Dev acc: 0.8700
# Epoch 19/30 | Train loss: 0.4044 | Dev acc: 0.8800
# Epoch 20/30 | Train loss: 0.1723 | Dev acc: 0.8700
# Epoch 21/30 | Train loss: 0.2476 | Dev acc: 0.8600
# Epoch 22/30 | Train loss: 0.2877 | Dev acc: 0.8700
# Epoch 23/30 | Train loss: 0.2960 | Dev acc: 0.8900
# Epoch 24/30 | Train loss: 0.3191 | Dev acc: 0.8800
# Epoch 25/30 | Train loss: 0.2488 | Dev acc: 0.8800
# Epoch 26/30 | Train loss: 0.3034 | Dev acc: 0.8900
# Epoch 27/30 | Train loss: 0.0611 | Dev acc: 0.8900
# Epoch 28/30 | Train loss: 0.1700 | Dev acc: 0.9000
# Epoch 29/30 | Train loss: 0.1414 | Dev acc: 0.8800
# Epoch 30/30 | Train loss: 0.1578 | Dev acc: 0.9100
# Dev accuracy: 0.9100
#
# Testing configuration:
# lr=0.001, hidden=64, layers=4, dropout=0.1
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.6938 | Dev acc: 0.5000
# Epoch 2/30 | Train loss: 0.6754 | Dev acc: 0.7200
# Epoch 3/30 | Train loss: 0.5827 | Dev acc: 0.7500
# Epoch 4/30 | Train loss: 0.4645 | Dev acc: 0.6900
# Epoch 5/30 | Train loss: 0.3937 | Dev acc: 0.7400
# Epoch 6/30 | Train loss: 0.4943 | Dev acc: 0.7600
# Epoch 7/30 | Train loss: 0.3845 | Dev acc: 0.8600
# Epoch 8/30 | Train loss: 0.1795 | Dev acc: 0.8300
# Epoch 9/30 | Train loss: 0.4741 | Dev acc: 0.8400
# Epoch 10/30 | Train loss: 0.4966 | Dev acc: 0.8800
# Epoch 11/30 | Train loss: 0.4001 | Dev acc: 0.8300
# Epoch 12/30 | Train loss: 0.1190 | Dev acc: 0.8800
# Epoch 13/30 | Train loss: 0.3018 | Dev acc: 0.8700
# Epoch 14/30 | Train loss: 0.2035 | Dev acc: 0.8800
# Epoch 15/30 | Train loss: 0.1452 | Dev acc: 0.8700
# Epoch 16/30 | Train loss: 0.1708 | Dev acc: 0.9200
# Epoch 17/30 | Train loss: 0.2171 | Dev acc: 0.8700
# Epoch 18/30 | Train loss: 0.2320 | Dev acc: 0.9000
# Epoch 19/30 | Train loss: 0.1475 | Dev acc: 0.9200
# Epoch 20/30 | Train loss: 0.1106 | Dev acc: 0.9100
# Epoch 21/30 | Train loss: 0.2795 | Dev acc: 0.9000
# Epoch 22/30 | Train loss: 0.1185 | Dev acc: 0.9200
# Epoch 23/30 | Train loss: 0.1729 | Dev acc: 0.9300
# Epoch 24/30 | Train loss: 0.2223 | Dev acc: 0.9300
# Epoch 25/30 | Train loss: 0.1218 | Dev acc: 0.8700
# Epoch 26/30 | Train loss: 0.4405 | Dev acc: 0.9200
# Epoch 27/30 | Train loss: 0.1438 | Dev acc: 0.9400
# Epoch 28/30 | Train loss: 0.1842 | Dev acc: 0.8900
# Epoch 29/30 | Train loss: 0.1964 | Dev acc: 0.9200
# Epoch 30/30 | Train loss: 0.1602 | Dev acc: 0.9200
# Dev accuracy: 0.9400
#
# Testing configuration:
# lr=0.001, hidden=64, layers=4, dropout=0.3
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.6865 | Dev acc: 0.5000
# Epoch 2/30 | Train loss: 0.6914 | Dev acc: 0.4900
# Epoch 3/30 | Train loss: 0.6596 | Dev acc: 0.7000
# Epoch 4/30 | Train loss: 0.5680 | Dev acc: 0.7100
# Epoch 5/30 | Train loss: 0.4529 | Dev acc: 0.7900
# Epoch 6/30 | Train loss: 0.5561 | Dev acc: 0.8700
# Epoch 7/30 | Train loss: 0.3469 | Dev acc: 0.8600
# Epoch 8/30 | Train loss: 0.4498 | Dev acc: 0.8600
# Epoch 9/30 | Train loss: 0.2057 | Dev acc: 0.8400
# Epoch 10/30 | Train loss: 0.1808 | Dev acc: 0.8500
# Epoch 11/30 | Train loss: 0.2007 | Dev acc: 0.8600
# Epoch 12/30 | Train loss: 0.5102 | Dev acc: 0.8400
# Epoch 13/30 | Train loss: 0.1273 | Dev acc: 0.8500
# Epoch 14/30 | Train loss: 0.3476 | Dev acc: 0.8700
# Epoch 15/30 | Train loss: 0.1490 | Dev acc: 0.8600
# Epoch 16/30 | Train loss: 0.1786 | Dev acc: 0.9000
# Epoch 17/30 | Train loss: 0.3912 | Dev acc: 0.8800
# Epoch 18/30 | Train loss: 0.3839 | Dev acc: 0.9200
# Epoch 19/30 | Train loss: 0.1556 | Dev acc: 0.9100
# Epoch 20/30 | Train loss: 0.1189 | Dev acc: 0.8700
# Epoch 21/30 | Train loss: 0.1576 | Dev acc: 0.9100
# Epoch 22/30 | Train loss: 0.4139 | Dev acc: 0.8700
# Epoch 23/30 | Train loss: 0.3007 | Dev acc: 0.9000
# Epoch 24/30 | Train loss: 0.1861 | Dev acc: 0.9000
# Epoch 25/30 | Train loss: 0.3037 | Dev acc: 0.9300
# Epoch 26/30 | Train loss: 0.2143 | Dev acc: 0.9300
# Epoch 27/30 | Train loss: 0.0915 | Dev acc: 0.8900
# Epoch 28/30 | Train loss: 0.2741 | Dev acc: 0.9100
# Epoch 29/30 | Train loss: 0.3461 | Dev acc: 0.9300
# Epoch 30/30 | Train loss: 0.2256 | Dev acc: 0.8900
# Dev accuracy: 0.9300
#
# Testing configuration:
# lr=0.001, hidden=128, layers=2, dropout=0.1
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.6821 | Dev acc: 0.7000
# Epoch 2/30 | Train loss: 0.6322 | Dev acc: 0.6700
# Epoch 3/30 | Train loss: 0.5385 | Dev acc: 0.7100
# Epoch 4/30 | Train loss: 0.4695 | Dev acc: 0.7900
# Epoch 5/30 | Train loss: 0.4302 | Dev acc: 0.8200
# Epoch 6/30 | Train loss: 0.4102 | Dev acc: 0.8500
# Epoch 7/30 | Train loss: 0.2006 | Dev acc: 0.8300
# Epoch 8/30 | Train loss: 0.3050 | Dev acc: 0.8400
# Epoch 9/30 | Train loss: 0.1595 | Dev acc: 0.8500
# Epoch 10/30 | Train loss: 0.3061 | Dev acc: 0.8600
# Epoch 11/30 | Train loss: 0.1167 | Dev acc: 0.8600
# Epoch 12/30 | Train loss: 0.2009 | Dev acc: 0.8700
# Epoch 13/30 | Train loss: 0.2251 | Dev acc: 0.9000
# Epoch 14/30 | Train loss: 0.2185 | Dev acc: 0.8600
# Epoch 15/30 | Train loss: 0.1454 | Dev acc: 0.8600
# Epoch 16/30 | Train loss: 0.1134 | Dev acc: 0.8700
# Epoch 17/30 | Train loss: 0.2337 | Dev acc: 0.8800
# Epoch 18/30 | Train loss: 0.2274 | Dev acc: 0.9100
# Epoch 19/30 | Train loss: 0.0801 | Dev acc: 0.9100
# Epoch 20/30 | Train loss: 0.1338 | Dev acc: 0.9300
# Epoch 21/30 | Train loss: 0.0301 | Dev acc: 0.9300
# Epoch 22/30 | Train loss: 0.2416 | Dev acc: 0.8700
# Epoch 23/30 | Train loss: 0.0889 | Dev acc: 0.8800
# Epoch 24/30 | Train loss: 0.1082 | Dev acc: 0.9000
# Epoch 25/30 | Train loss: 0.1216 | Dev acc: 0.9400
# Epoch 26/30 | Train loss: 0.0870 | Dev acc: 0.9300
# Epoch 27/30 | Train loss: 0.1299 | Dev acc: 0.9500
# Epoch 28/30 | Train loss: 0.0441 | Dev acc: 0.9000
# Epoch 29/30 | Train loss: 0.2396 | Dev acc: 0.9500
# Epoch 30/30 | Train loss: 0.2668 | Dev acc: 0.9100
# Dev accuracy: 0.9500
#
# Testing configuration:
# lr=0.001, hidden=128, layers=2, dropout=0.3
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.6781 | Dev acc: 0.5100
# Epoch 2/30 | Train loss: 0.6368 | Dev acc: 0.7200
# Epoch 3/30 | Train loss: 0.5736 | Dev acc: 0.7600
# Epoch 4/30 | Train loss: 0.4051 | Dev acc: 0.7500
# Epoch 5/30 | Train loss: 0.3545 | Dev acc: 0.8200
# Epoch 6/30 | Train loss: 0.3820 | Dev acc: 0.8500
# Epoch 7/30 | Train loss: 0.2675 | Dev acc: 0.8900
# Epoch 8/30 | Train loss: 0.2772 | Dev acc: 0.8300
# Epoch 9/30 | Train loss: 0.3521 | Dev acc: 0.8700
# Epoch 10/30 | Train loss: 0.2637 | Dev acc: 0.8700
# Epoch 11/30 | Train loss: 0.1562 | Dev acc: 0.8700
# Epoch 12/30 | Train loss: 0.2620 | Dev acc: 0.8700
# Epoch 13/30 | Train loss: 0.1722 | Dev acc: 0.8300
# Epoch 14/30 | Train loss: 0.2884 | Dev acc: 0.8800
# Epoch 15/30 | Train loss: 0.2454 | Dev acc: 0.8800
# Epoch 16/30 | Train loss: 0.2017 | Dev acc: 0.9100
# Epoch 17/30 | Train loss: 0.1981 | Dev acc: 0.8800
# Epoch 18/30 | Train loss: 0.1796 | Dev acc: 0.8800
# Epoch 19/30 | Train loss: 0.1222 | Dev acc: 0.9000
# Epoch 20/30 | Train loss: 0.3003 | Dev acc: 0.9000
# Epoch 21/30 | Train loss: 0.4300 | Dev acc: 0.9200
# Epoch 22/30 | Train loss: 0.3882 | Dev acc: 0.8700
# Epoch 23/30 | Train loss: 0.1947 | Dev acc: 0.9300
# Epoch 24/30 | Train loss: 0.0833 | Dev acc: 0.9200
# Epoch 25/30 | Train loss: 0.3044 | Dev acc: 0.9300
# Epoch 26/30 | Train loss: 0.2899 | Dev acc: 0.9100
# Epoch 27/30 | Train loss: 0.1908 | Dev acc: 0.9200
# Epoch 28/30 | Train loss: 0.1217 | Dev acc: 0.9400
# Epoch 29/30 | Train loss: 0.2334 | Dev acc: 0.9000
# Epoch 30/30 | Train loss: 0.1610 | Dev acc: 0.9200
# Dev accuracy: 0.9400
#
# Testing configuration:
# lr=0.001, hidden=128, layers=4, dropout=0.1
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.6853 | Dev acc: 0.6800
# Epoch 2/30 | Train loss: 0.5638 | Dev acc: 0.7200
# Epoch 3/30 | Train loss: 0.5465 | Dev acc: 0.7700
# Epoch 4/30 | Train loss: 0.4905 | Dev acc: 0.8300
# Epoch 5/30 | Train loss: 0.2748 | Dev acc: 0.8600
# Epoch 6/30 | Train loss: 0.2284 | Dev acc: 0.8600
# Epoch 7/30 | Train loss: 0.4304 | Dev acc: 0.8600
# Epoch 8/30 | Train loss: 0.2100 | Dev acc: 0.8800
# Epoch 9/30 | Train loss: 0.2352 | Dev acc: 0.8700
# Epoch 10/30 | Train loss: 0.1235 | Dev acc: 0.8900
# Epoch 11/30 | Train loss: 0.1600 | Dev acc: 0.8800
# Epoch 12/30 | Train loss: 0.2916 | Dev acc: 0.8400
# Epoch 13/30 | Train loss: 0.1029 | Dev acc: 0.8800
# Epoch 14/30 | Train loss: 0.0875 | Dev acc: 0.9000
# Epoch 15/30 | Train loss: 0.0786 | Dev acc: 0.8800
# Epoch 16/30 | Train loss: 0.2136 | Dev acc: 0.9300
# Epoch 17/30 | Train loss: 0.0394 | Dev acc: 0.9300
# Epoch 18/30 | Train loss: 0.1543 | Dev acc: 0.9200
# Epoch 19/30 | Train loss: 0.1443 | Dev acc: 0.9200
# Epoch 20/30 | Train loss: 0.1543 | Dev acc: 0.9100
# Epoch 21/30 | Train loss: 0.2281 | Dev acc: 0.8600
# Epoch 22/30 | Train loss: 0.4186 | Dev acc: 0.8300
# Early stopping at epoch 22
# Dev accuracy: 0.9300
#
# Testing configuration:
# lr=0.001, hidden=128, layers=4, dropout=0.3
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.6954 | Dev acc: 0.5200
# Epoch 2/30 | Train loss: 0.6700 | Dev acc: 0.6200
# Epoch 3/30 | Train loss: 0.6287 | Dev acc: 0.7400
# Epoch 4/30 | Train loss: 0.4868 | Dev acc: 0.8200
# Epoch 5/30 | Train loss: 0.4071 | Dev acc: 0.8800
# Epoch 6/30 | Train loss: 0.2152 | Dev acc: 0.8600
# Epoch 7/30 | Train loss: 0.2569 | Dev acc: 0.8500
# Epoch 8/30 | Train loss: 0.2624 | Dev acc: 0.8500
# Epoch 9/30 | Train loss: 0.3725 | Dev acc: 0.8800
# Epoch 10/30 | Train loss: 0.3019 | Dev acc: 0.8800
# Epoch 11/30 | Train loss: 0.1034 | Dev acc: 0.8900
# Epoch 12/30 | Train loss: 0.2925 | Dev acc: 0.9000
# Epoch 13/30 | Train loss: 0.2306 | Dev acc: 0.9000
# Epoch 14/30 | Train loss: 0.2377 | Dev acc: 0.9000
# Epoch 15/30 | Train loss: 0.2151 | Dev acc: 0.9000
# Epoch 16/30 | Train loss: 0.1442 | Dev acc: 0.8900
# Epoch 17/30 | Train loss: 0.4281 | Dev acc: 0.9300
# Epoch 18/30 | Train loss: 0.1849 | Dev acc: 0.9300
# Epoch 19/30 | Train loss: 0.1077 | Dev acc: 0.9300
# Epoch 20/30 | Train loss: 0.1085 | Dev acc: 0.8800
# Epoch 21/30 | Train loss: 0.2879 | Dev acc: 0.8800
# Epoch 22/30 | Train loss: 0.2676 | Dev acc: 0.9300
# Epoch 23/30 | Train loss: 0.0831 | Dev acc: 0.8100
# Epoch 24/30 | Train loss: 0.0812 | Dev acc: 0.9200
# Early stopping at epoch 24
# Dev accuracy: 0.9300
#
# Testing configuration:
# lr=0.0005, hidden=64, layers=2, dropout=0.1
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.6844 | Dev acc: 0.5300
# Epoch 2/30 | Train loss: 0.6819 | Dev acc: 0.5000
# Epoch 3/30 | Train loss: 0.6663 | Dev acc: 0.7700
# Epoch 4/30 | Train loss: 0.6253 | Dev acc: 0.7600
# Epoch 5/30 | Train loss: 0.5922 | Dev acc: 0.6200
# Epoch 6/30 | Train loss: 0.5771 | Dev acc: 0.7400
# Epoch 7/30 | Train loss: 0.4820 | Dev acc: 0.7400
# Epoch 8/30 | Train loss: 0.4779 | Dev acc: 0.7600
# Epoch 9/30 | Train loss: 0.5361 | Dev acc: 0.7800
# Epoch 10/30 | Train loss: 0.3186 | Dev acc: 0.8000
# Epoch 11/30 | Train loss: 0.3578 | Dev acc: 0.8000
# Epoch 12/30 | Train loss: 0.5485 | Dev acc: 0.8600
# Epoch 13/30 | Train loss: 0.3667 | Dev acc: 0.8500
# Epoch 14/30 | Train loss: 0.2848 | Dev acc: 0.8500
# Epoch 15/30 | Train loss: 0.3915 | Dev acc: 0.8600
# Epoch 16/30 | Train loss: 0.3670 | Dev acc: 0.8600
# Epoch 17/30 | Train loss: 0.1937 | Dev acc: 0.8600
# Epoch 18/30 | Train loss: 0.2243 | Dev acc: 0.8600
# Epoch 19/30 | Train loss: 0.2149 | Dev acc: 0.8700
# Epoch 20/30 | Train loss: 0.2417 | Dev acc: 0.8500
# Epoch 21/30 | Train loss: 0.1738 | Dev acc: 0.8700
# Epoch 22/30 | Train loss: 0.1904 | Dev acc: 0.8700
# Epoch 23/30 | Train loss: 0.3448 | Dev acc: 0.8800
# Epoch 24/30 | Train loss: 0.1825 | Dev acc: 0.8800
# Epoch 25/30 | Train loss: 0.2668 | Dev acc: 0.8800
# Epoch 26/30 | Train loss: 0.2413 | Dev acc: 0.8700
# Epoch 27/30 | Train loss: 0.2987 | Dev acc: 0.8600
# Epoch 28/30 | Train loss: 0.2499 | Dev acc: 0.8600
# Epoch 29/30 | Train loss: 0.3273 | Dev acc: 0.8800
# Epoch 30/30 | Train loss: 0.1539 | Dev acc: 0.8900
# Dev accuracy: 0.8900
#
# Testing configuration:
# lr=0.0005, hidden=64, layers=2, dropout=0.3
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.6925 | Dev acc: 0.6400
# Epoch 2/30 | Train loss: 0.6821 | Dev acc: 0.6900
# Epoch 3/30 | Train loss: 0.6876 | Dev acc: 0.6800
# Epoch 4/30 | Train loss: 0.6673 | Dev acc: 0.6900
# Epoch 5/30 | Train loss: 0.6689 | Dev acc: 0.7100
# Epoch 6/30 | Train loss: 0.6230 | Dev acc: 0.7200
# Epoch 7/30 | Train loss: 0.5719 | Dev acc: 0.7200
# Epoch 8/30 | Train loss: 0.5157 | Dev acc: 0.7400
# Epoch 9/30 | Train loss: 0.5383 | Dev acc: 0.7400
# Epoch 10/30 | Train loss: 0.5064 | Dev acc: 0.7600
# Epoch 11/30 | Train loss: 0.5383 | Dev acc: 0.8100
# Epoch 12/30 | Train loss: 0.4359 | Dev acc: 0.7900
# Epoch 13/30 | Train loss: 0.3542 | Dev acc: 0.8400
# Epoch 14/30 | Train loss: 0.4702 | Dev acc: 0.8200
# Epoch 15/30 | Train loss: 0.2700 | Dev acc: 0.8400
# Epoch 16/30 | Train loss: 0.2957 | Dev acc: 0.8400
# Epoch 17/30 | Train loss: 0.4097 | Dev acc: 0.8300
# Epoch 18/30 | Train loss: 0.4977 | Dev acc: 0.8700
# Epoch 19/30 | Train loss: 0.2445 | Dev acc: 0.8600
# Epoch 20/30 | Train loss: 0.2098 | Dev acc: 0.8700
# Epoch 21/30 | Train loss: 0.3016 | Dev acc: 0.8400
# Epoch 22/30 | Train loss: 0.5209 | Dev acc: 0.8700
# Epoch 23/30 | Train loss: 0.3160 | Dev acc: 0.8300
# Epoch 24/30 | Train loss: 0.4035 | Dev acc: 0.8600
# Epoch 25/30 | Train loss: 0.1707 | Dev acc: 0.8600
# Epoch 26/30 | Train loss: 0.1953 | Dev acc: 0.8600
# Epoch 27/30 | Train loss: 0.3960 | Dev acc: 0.8600
# Epoch 28/30 | Train loss: 0.2303 | Dev acc: 0.8700
# Epoch 29/30 | Train loss: 0.2323 | Dev acc: 0.8600
# Epoch 30/30 | Train loss: 0.2964 | Dev acc: 0.8700
# Dev accuracy: 0.8700
#
# Testing configuration:
# lr=0.0005, hidden=64, layers=4, dropout=0.1
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.6939 | Dev acc: 0.5000
# Epoch 2/30 | Train loss: 0.6856 | Dev acc: 0.5000
# Epoch 3/30 | Train loss: 0.6702 | Dev acc: 0.7100
# Epoch 4/30 | Train loss: 0.6034 | Dev acc: 0.7300
# Epoch 5/30 | Train loss: 0.5937 | Dev acc: 0.7600
# Epoch 6/30 | Train loss: 0.3370 | Dev acc: 0.8100
# Epoch 7/30 | Train loss: 0.4476 | Dev acc: 0.8300
# Epoch 8/30 | Train loss: 0.3199 | Dev acc: 0.8400
# Epoch 9/30 | Train loss: 0.2684 | Dev acc: 0.8700
# Epoch 10/30 | Train loss: 0.3089 | Dev acc: 0.8400
# Epoch 11/30 | Train loss: 0.1541 | Dev acc: 0.8700
# Epoch 12/30 | Train loss: 0.1880 | Dev acc: 0.8900
# Epoch 13/30 | Train loss: 0.3422 | Dev acc: 0.8700
# Epoch 14/30 | Train loss: 0.1251 | Dev acc: 0.8800
# Epoch 15/30 | Train loss: 0.3793 | Dev acc: 0.9000
# Epoch 16/30 | Train loss: 0.1866 | Dev acc: 0.9100
# Epoch 17/30 | Train loss: 0.2411 | Dev acc: 0.9000
# Epoch 18/30 | Train loss: 0.0871 | Dev acc: 0.8800
# Epoch 19/30 | Train loss: 0.2524 | Dev acc: 0.8800
# Epoch 20/30 | Train loss: 0.0933 | Dev acc: 0.9000
# Epoch 21/30 | Train loss: 0.1673 | Dev acc: 0.8800
# Epoch 22/30 | Train loss: 0.2507 | Dev acc: 0.9200
# Epoch 23/30 | Train loss: 0.2111 | Dev acc: 0.9200
# Epoch 24/30 | Train loss: 0.2197 | Dev acc: 0.9200
# Epoch 25/30 | Train loss: 0.2037 | Dev acc: 0.9100
# Epoch 26/30 | Train loss: 0.2375 | Dev acc: 0.9100
# Epoch 27/30 | Train loss: 0.2244 | Dev acc: 0.8900
# Epoch 28/30 | Train loss: 0.0898 | Dev acc: 0.9200
# Epoch 29/30 | Train loss: 0.1074 | Dev acc: 0.9300
# Epoch 30/30 | Train loss: 0.1185 | Dev acc: 0.9300
# Dev accuracy: 0.9300
#
# Testing configuration:
# lr=0.0005, hidden=64, layers=4, dropout=0.3
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.6961 | Dev acc: 0.5000
# Epoch 2/30 | Train loss: 0.6942 | Dev acc: 0.5000
# Epoch 3/30 | Train loss: 0.6918 | Dev acc: 0.5000
# Epoch 4/30 | Train loss: 0.6931 | Dev acc: 0.7200
# Epoch 5/30 | Train loss: 0.6669 | Dev acc: 0.6900
# Epoch 6/30 | Train loss: 0.5582 | Dev acc: 0.7400
# Epoch 7/30 | Train loss: 0.4148 | Dev acc: 0.7500
# Epoch 8/30 | Train loss: 0.5203 | Dev acc: 0.7800
# Epoch 9/30 | Train loss: 0.4307 | Dev acc: 0.8100
# Epoch 10/30 | Train loss: 0.3581 | Dev acc: 0.8400
# Epoch 11/30 | Train loss: 0.2628 | Dev acc: 0.8800
# Epoch 12/30 | Train loss: 0.3992 | Dev acc: 0.8800
# Epoch 13/30 | Train loss: 0.2927 | Dev acc: 0.8500
# Epoch 14/30 | Train loss: 0.3223 | Dev acc: 0.8700
# Epoch 15/30 | Train loss: 0.2182 | Dev acc: 0.8800
# Epoch 16/30 | Train loss: 0.3502 | Dev acc: 0.9000
# Epoch 17/30 | Train loss: 0.1110 | Dev acc: 0.9000
# Epoch 18/30 | Train loss: 0.2102 | Dev acc: 0.8900
# Epoch 19/30 | Train loss: 0.1884 | Dev acc: 0.8900
# Epoch 20/30 | Train loss: 0.1937 | Dev acc: 0.8700
# Epoch 21/30 | Train loss: 0.0766 | Dev acc: 0.8900
# Epoch 22/30 | Train loss: 0.1413 | Dev acc: 0.9000
# Epoch 23/30 | Train loss: 0.1835 | Dev acc: 0.9100
# Epoch 24/30 | Train loss: 0.1664 | Dev acc: 0.9000
# Epoch 25/30 | Train loss: 0.1060 | Dev acc: 0.9100
# Epoch 26/30 | Train loss: 0.1817 | Dev acc: 0.9200
# Epoch 27/30 | Train loss: 0.3802 | Dev acc: 0.9100
# Epoch 28/30 | Train loss: 0.0812 | Dev acc: 0.9200
# Epoch 29/30 | Train loss: 0.1349 | Dev acc: 0.9000
# Epoch 30/30 | Train loss: 0.3626 | Dev acc: 0.9200
# Dev accuracy: 0.9200
#
# Testing configuration:
# lr=0.0005, hidden=128, layers=2, dropout=0.1
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.6791 | Dev acc: 0.5300
# Epoch 2/30 | Train loss: 0.6694 | Dev acc: 0.6900
# Epoch 3/30 | Train loss: 0.6446 | Dev acc: 0.7400
# Epoch 4/30 | Train loss: 0.5672 | Dev acc: 0.7300
# Epoch 5/30 | Train loss: 0.4436 | Dev acc: 0.7800
# Epoch 6/30 | Train loss: 0.4053 | Dev acc: 0.7800
# Epoch 7/30 | Train loss: 0.4586 | Dev acc: 0.8300
# Epoch 8/30 | Train loss: 0.3142 | Dev acc: 0.8600
# Epoch 9/30 | Train loss: 0.3804 | Dev acc: 0.8700
# Epoch 10/30 | Train loss: 0.3643 | Dev acc: 0.8700
# Epoch 11/30 | Train loss: 0.4792 | Dev acc: 0.8700
# Epoch 12/30 | Train loss: 0.1683 | Dev acc: 0.8700
# Epoch 13/30 | Train loss: 0.1464 | Dev acc: 0.8700
# Epoch 14/30 | Train loss: 0.2824 | Dev acc: 0.8700
# Epoch 15/30 | Train loss: 0.2951 | Dev acc: 0.8800
# Epoch 16/30 | Train loss: 0.3147 | Dev acc: 0.8700
# Epoch 17/30 | Train loss: 0.0798 | Dev acc: 0.8900
# Epoch 18/30 | Train loss: 0.0623 | Dev acc: 0.8900
# Epoch 19/30 | Train loss: 0.2047 | Dev acc: 0.8900
# Epoch 20/30 | Train loss: 0.3298 | Dev acc: 0.8800
# Epoch 21/30 | Train loss: 0.1735 | Dev acc: 0.8900
# Epoch 22/30 | Train loss: 0.2670 | Dev acc: 0.8700
# Epoch 23/30 | Train loss: 0.0801 | Dev acc: 0.9100
# Epoch 24/30 | Train loss: 0.1321 | Dev acc: 0.9000
# Epoch 25/30 | Train loss: 0.2575 | Dev acc: 0.9100
# Epoch 26/30 | Train loss: 0.1381 | Dev acc: 0.9200
# Epoch 27/30 | Train loss: 0.2510 | Dev acc: 0.9300
# Epoch 28/30 | Train loss: 0.1238 | Dev acc: 0.9100
# Epoch 29/30 | Train loss: 0.2195 | Dev acc: 0.8800
# Epoch 30/30 | Train loss: 0.0787 | Dev acc: 0.9200
# Dev accuracy: 0.9200
#
# Testing configuration:
# lr=0.0005, hidden=128, layers=2, dropout=0.3
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.6923 | Dev acc: 0.5000
# Epoch 2/30 | Train loss: 0.6732 | Dev acc: 0.6800
# Epoch 3/30 | Train loss: 0.6666 | Dev acc: 0.6900
# Epoch 4/30 | Train loss: 0.6088 | Dev acc: 0.6900
# Epoch 5/30 | Train loss: 0.5622 | Dev acc: 0.7600
# Epoch 6/30 | Train loss: 0.5184 | Dev acc: 0.7300
# Epoch 7/30 | Train loss: 0.3917 | Dev acc: 0.7700
# Epoch 8/30 | Train loss: 0.4214 | Dev acc: 0.8100
# Epoch 9/30 | Train loss: 0.4126 | Dev acc: 0.7900
# Epoch 10/30 | Train loss: 0.4318 | Dev acc: 0.8400
# Epoch 11/30 | Train loss: 0.4648 | Dev acc: 0.8600
# Epoch 12/30 | Train loss: 0.2723 | Dev acc: 0.8700
# Epoch 13/30 | Train loss: 0.2482 | Dev acc: 0.8700
# Epoch 14/30 | Train loss: 0.4262 | Dev acc: 0.8600
# Epoch 15/30 | Train loss: 0.3311 | Dev acc: 0.8700
# Epoch 16/30 | Train loss: 0.2616 | Dev acc: 0.8800
# Epoch 17/30 | Train loss: 0.3361 | Dev acc: 0.8700
# Epoch 18/30 | Train loss: 0.2028 | Dev acc: 0.8400
# Epoch 19/30 | Train loss: 0.4429 | Dev acc: 0.8700
# Epoch 20/30 | Train loss: 0.3211 | Dev acc: 0.8800
# Epoch 21/30 | Train loss: 0.1887 | Dev acc: 0.8800
# Epoch 22/30 | Train loss: 0.1081 | Dev acc: 0.8900
# Epoch 23/30 | Train loss: 0.2060 | Dev acc: 0.8800
# Epoch 24/30 | Train loss: 0.3394 | Dev acc: 0.8800
# Epoch 25/30 | Train loss: 0.2201 | Dev acc: 0.8900
# Epoch 26/30 | Train loss: 0.1589 | Dev acc: 0.8900
# Epoch 27/30 | Train loss: 0.3235 | Dev acc: 0.8900
# Epoch 28/30 | Train loss: 0.1131 | Dev acc: 0.9100
# Epoch 29/30 | Train loss: 0.2091 | Dev acc: 0.9100
# Epoch 30/30 | Train loss: 0.1302 | Dev acc: 0.9100
# Dev accuracy: 0.9100
#
# Testing configuration:
# lr=0.0005, hidden=128, layers=4, dropout=0.1
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.6905 | Dev acc: 0.6100
# Epoch 2/30 | Train loss: 0.6625 | Dev acc: 0.6100
# Epoch 3/30 | Train loss: 0.5905 | Dev acc: 0.7000
# Epoch 4/30 | Train loss: 0.4940 | Dev acc: 0.7800
# Epoch 5/30 | Train loss: 0.3205 | Dev acc: 0.8300
# Epoch 6/30 | Train loss: 0.3292 | Dev acc: 0.8600
# Epoch 7/30 | Train loss: 0.4280 | Dev acc: 0.8700
# Epoch 8/30 | Train loss: 0.2902 | Dev acc: 0.8800
# Epoch 9/30 | Train loss: 0.2369 | Dev acc: 0.8600
# Epoch 10/30 | Train loss: 0.3430 | Dev acc: 0.8700
# Epoch 11/30 | Train loss: 0.1616 | Dev acc: 0.8900
# Epoch 12/30 | Train loss: 0.2558 | Dev acc: 0.8800
# Epoch 13/30 | Train loss: 0.0828 | Dev acc: 0.8900
# Epoch 14/30 | Train loss: 0.1189 | Dev acc: 0.9100
# Epoch 15/30 | Train loss: 0.2160 | Dev acc: 0.8800
# Epoch 16/30 | Train loss: 0.2508 | Dev acc: 0.9100
# Epoch 17/30 | Train loss: 0.2505 | Dev acc: 0.9100
# Epoch 18/30 | Train loss: 0.3975 | Dev acc: 0.9000
# Epoch 19/30 | Train loss: 0.0739 | Dev acc: 0.9000
# Epoch 20/30 | Train loss: 0.1849 | Dev acc: 0.9300
# Epoch 21/30 | Train loss: 0.2025 | Dev acc: 0.9300
# Epoch 22/30 | Train loss: 0.2488 | Dev acc: 0.9000
# Epoch 23/30 | Train loss: 0.2261 | Dev acc: 0.9300
# Epoch 24/30 | Train loss: 0.1165 | Dev acc: 0.9400
# Epoch 25/30 | Train loss: 0.1001 | Dev acc: 0.9200
# Epoch 26/30 | Train loss: 0.0847 | Dev acc: 0.8900
# Epoch 27/30 | Train loss: 0.3091 | Dev acc: 0.9200
# Epoch 28/30 | Train loss: 0.1131 | Dev acc: 0.9200
# Epoch 29/30 | Train loss: 0.1768 | Dev acc: 0.9300
# Early stopping at epoch 29
# Dev accuracy: 0.9400
#
# Testing configuration:
# lr=0.0005, hidden=128, layers=4, dropout=0.3
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.6929 | Dev acc: 0.5000
# Epoch 2/30 | Train loss: 0.6906 | Dev acc: 0.5000
# Epoch 3/30 | Train loss: 0.6752 | Dev acc: 0.6900
# Epoch 4/30 | Train loss: 0.6460 | Dev acc: 0.7300
# Epoch 5/30 | Train loss: 0.5661 | Dev acc: 0.6400
# Epoch 6/30 | Train loss: 0.5185 | Dev acc: 0.8100
# Epoch 7/30 | Train loss: 0.2756 | Dev acc: 0.8600
# Epoch 8/30 | Train loss: 0.2388 | Dev acc: 0.8300
# Epoch 9/30 | Train loss: 0.2979 | Dev acc: 0.8700
# Epoch 10/30 | Train loss: 0.2776 | Dev acc: 0.8700
# Epoch 11/30 | Train loss: 0.2658 | Dev acc: 0.8700
# Epoch 12/30 | Train loss: 0.3306 | Dev acc: 0.8800
# Epoch 13/30 | Train loss: 0.1294 | Dev acc: 0.8800
# Epoch 14/30 | Train loss: 0.0958 | Dev acc: 0.8700
# Epoch 15/30 | Train loss: 0.1723 | Dev acc: 0.8800
# Epoch 16/30 | Train loss: 0.1294 | Dev acc: 0.9000
# Epoch 17/30 | Train loss: 0.3601 | Dev acc: 0.8900
# Epoch 18/30 | Train loss: 0.4124 | Dev acc: 0.9100
# Epoch 19/30 | Train loss: 0.1532 | Dev acc: 0.9100
# Epoch 20/30 | Train loss: 0.3340 | Dev acc: 0.9000
# Epoch 21/30 | Train loss: 0.2876 | Dev acc: 0.9200
# Epoch 22/30 | Train loss: 0.1699 | Dev acc: 0.9400
# Epoch 23/30 | Train loss: 0.2363 | Dev acc: 0.9200
# Epoch 24/30 | Train loss: 0.3146 | Dev acc: 0.9200
# Epoch 25/30 | Train loss: 0.1557 | Dev acc: 0.9200
# Epoch 26/30 | Train loss: 0.2929 | Dev acc: 0.9100
# Epoch 27/30 | Train loss: 0.2611 | Dev acc: 0.9300
# Early stopping at epoch 27
# Dev accuracy: 0.9400

# %%
with torch.no_grad():
    pred_nn = (
        best_model(X_test).squeeze() > 0.5
    ).int().numpy()

results_nn = evaluate_model(
    best_model,
    X_test,
    y_test
)

print("Best parameters:")
print(best_params)

print("\nTest metrics:")
print(results_nn)
# Out:
# Best parameters:
# {'learning_rate': 0.001, 'hidden_size': 128, 'n_layers': 2, 'dropout': 0.1}
#
# Test metrics:
# {'Accuracy': 0.96, 'Precision': 0.9423076923076923, 'Recall': 0.98, 'F1-score': 0.9607843137254902}

# %%
# Diagnosis of the NN
best_model.eval()

with torch.no_grad():
    y_train_pred = best_model(X_train)

y_train_pred = (y_train_pred > 0.5).int()

acc = accuracy_score(y_train.numpy(), y_train_pred.numpy())
print(f"Train accuracy: {acc:.4f}")
# Out:
# Train accuracy: 0.9463

# %% [markdown]
# ### NN with linguistic features

# %%
# Convert data to PyTorch tensors

X_train_ling = torch.tensor(
    X_train_ling.to_numpy(),
    dtype=torch.float32
)

X_dev_ling = torch.tensor(
    X_dev_ling.to_numpy(),
    dtype=torch.float32
)

X_test_ling = torch.tensor(
    X_test_ling.to_numpy(),
    dtype=torch.float32
)

y_train_ling = torch.tensor(
    y_train_ling.to_numpy(),
    dtype=torch.float32
)

y_dev_ling = torch.tensor(
    y_dev_ling.to_numpy(),
    dtype=torch.float32
)

y_test_ling = torch.tensor(
    y_test_ling.to_numpy(),
    dtype=torch.float32
)

# %%
# Hyperparameters to test
param_grid = {
    "learning_rate": [1e-3, 5e-4],
    "hidden_size": [64, 128],
    "n_layers": [2, 4],
    "dropout": [0.1, 0.3]
}

best_model_ling = None
best_params_ling = None
best_dev_acc_ling = 0

# Iterate through all hyperparameter combinations

for lr in param_grid["learning_rate"]:
    for hs in param_grid["hidden_size"]:
        for nl in param_grid["n_layers"]:
            for dr in param_grid["dropout"]:
                print("\nTesting configuration:")

                print(
                    f"lr={lr}, "
                    f"hidden={hs}, "
                    f"layers={nl}, "
                    f"dropout={dr}"
                )

                model_ling, dev_acc_ling = train(
                    X_train_ling,
                    y_train_ling,
                    X_dev_ling,
                    y_dev_ling,
                    X_test_ling,
                    y_test_ling,
                    num_epochs=30,
                    learning_rate=lr,
                    hidden_size=hs,
                    n_layers=nl,
                    dropout=dr
                )

                print(
                    f"Dev accuracy: "
                    f"{dev_acc_ling:.4f}"
                )

                # Keep best model
                if dev_acc_ling > best_dev_acc_ling:
                    best_dev_acc_ling = dev_acc_ling
                    best_model_ling = model_ling
                    best_params_ling = {
                        "learning_rate": lr,
                        "hidden_size": hs,
                        "n_layers": nl,
                        "dropout": dr
                    }
# Out:
# Testing configuration:
# lr=0.001, hidden=64, layers=2, dropout=0.1
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.5128 | Dev acc: 0.6900
# Epoch 2/30 | Train loss: 0.5015 | Dev acc: 0.7300
# Epoch 3/30 | Train loss: 0.5334 | Dev acc: 0.7600
# Epoch 4/30 | Train loss: 0.4187 | Dev acc: 0.7700
# Epoch 5/30 | Train loss: 0.3557 | Dev acc: 0.7800
# Epoch 6/30 | Train loss: 0.7989 | Dev acc: 0.7700
# Epoch 7/30 | Train loss: 0.5228 | Dev acc: 0.7800
# Epoch 8/30 | Train loss: 0.4625 | Dev acc: 0.7700
# Epoch 9/30 | Train loss: 0.2928 | Dev acc: 0.7600
# Epoch 10/30 | Train loss: 0.3487 | Dev acc: 0.8000
# Epoch 11/30 | Train loss: 0.5082 | Dev acc: 0.7800
# Epoch 12/30 | Train loss: 0.2925 | Dev acc: 0.7200
# Epoch 13/30 | Train loss: 0.2132 | Dev acc: 0.7800
# Epoch 14/30 | Train loss: 0.4113 | Dev acc: 0.7900
# Epoch 15/30 | Train loss: 0.3572 | Dev acc: 0.7800
# Epoch 16/30 | Train loss: 0.4670 | Dev acc: 0.7500
# Early stopping at epoch 16
# Dev accuracy: 0.7800
#
# Testing configuration:
# lr=0.001, hidden=64, layers=2, dropout=0.3
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.6758 | Dev acc: 0.6700
# Epoch 2/30 | Train loss: 0.5289 | Dev acc: 0.7200
# Epoch 3/30 | Train loss: 0.6253 | Dev acc: 0.7400
# Epoch 4/30 | Train loss: 0.4517 | Dev acc: 0.7800
# Epoch 5/30 | Train loss: 0.5161 | Dev acc: 0.7900
# Epoch 6/30 | Train loss: 0.4249 | Dev acc: 0.7800
# Epoch 7/30 | Train loss: 0.4294 | Dev acc: 0.7600
# Epoch 8/30 | Train loss: 0.3784 | Dev acc: 0.7800
# Epoch 9/30 | Train loss: 0.4001 | Dev acc: 0.7700
# Epoch 10/30 | Train loss: 0.3762 | Dev acc: 0.7700
# Epoch 11/30 | Train loss: 0.4269 | Dev acc: 0.7800
# Epoch 12/30 | Train loss: 0.4391 | Dev acc: 0.7600
# Epoch 13/30 | Train loss: 0.4990 | Dev acc: 0.7600
# Epoch 14/30 | Train loss: 0.4873 | Dev acc: 0.7800
# Epoch 15/30 | Train loss: 0.5329 | Dev acc: 0.7700
# Epoch 16/30 | Train loss: 0.3722 | Dev acc: 0.7700
# Epoch 17/30 | Train loss: 0.3718 | Dev acc: 0.7400
# Epoch 18/30 | Train loss: 0.2958 | Dev acc: 0.7900
# Epoch 19/30 | Train loss: 0.4195 | Dev acc: 0.7600
# Early stopping at epoch 19
# Dev accuracy: 0.7800
#
# Testing configuration:
# lr=0.001, hidden=64, layers=4, dropout=0.1
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.6223 | Dev acc: 0.7400
# Epoch 2/30 | Train loss: 0.7238 | Dev acc: 0.7800
# Epoch 3/30 | Train loss: 0.3937 | Dev acc: 0.8000
# Epoch 4/30 | Train loss: 0.5806 | Dev acc: 0.7600
# Epoch 5/30 | Train loss: 0.4156 | Dev acc: 0.7700
# Epoch 6/30 | Train loss: 0.4140 | Dev acc: 0.7700
# Epoch 7/30 | Train loss: 0.2376 | Dev acc: 0.7800
# Epoch 8/30 | Train loss: 0.3827 | Dev acc: 0.7900
# Epoch 9/30 | Train loss: 0.5014 | Dev acc: 0.7900
# Epoch 10/30 | Train loss: 0.4473 | Dev acc: 0.7800
# Epoch 11/30 | Train loss: 0.5092 | Dev acc: 0.7400
# Epoch 12/30 | Train loss: 0.4282 | Dev acc: 0.7100
# Epoch 13/30 | Train loss: 0.3330 | Dev acc: 0.7900
# Epoch 14/30 | Train loss: 0.2475 | Dev acc: 0.7900
# Epoch 15/30 | Train loss: 0.3294 | Dev acc: 0.7700
# Epoch 16/30 | Train loss: 0.3820 | Dev acc: 0.7700
# Epoch 17/30 | Train loss: 0.4281 | Dev acc: 0.7400
# Epoch 18/30 | Train loss: 0.6725 | Dev acc: 0.7800
# Epoch 19/30 | Train loss: 0.4990 | Dev acc: 0.7800
# Epoch 20/30 | Train loss: 0.3445 | Dev acc: 0.7800
# Epoch 21/30 | Train loss: 0.3221 | Dev acc: 0.8000
# Epoch 22/30 | Train loss: 0.4536 | Dev acc: 0.7900
# Epoch 23/30 | Train loss: 0.4518 | Dev acc: 0.7800
# Epoch 24/30 | Train loss: 0.3042 | Dev acc: 0.7800
# Epoch 25/30 | Train loss: 0.5207 | Dev acc: 0.7700
# Epoch 26/30 | Train loss: 0.4262 | Dev acc: 0.7600
# Epoch 27/30 | Train loss: 0.3634 | Dev acc: 0.7900
# Epoch 28/30 | Train loss: 0.4814 | Dev acc: 0.7700
# Epoch 29/30 | Train loss: 0.3154 | Dev acc: 0.7600
# Epoch 30/30 | Train loss: 0.4857 | Dev acc: 0.7700
# Dev accuracy: 0.7700
#
# Testing configuration:
# lr=0.001, hidden=64, layers=4, dropout=0.3
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.6617 | Dev acc: 0.6500
# Epoch 2/30 | Train loss: 0.5768 | Dev acc: 0.6900
# Epoch 3/30 | Train loss: 0.5008 | Dev acc: 0.7400
# Epoch 4/30 | Train loss: 0.5027 | Dev acc: 0.7700
# Epoch 5/30 | Train loss: 0.4831 | Dev acc: 0.7600
# Epoch 6/30 | Train loss: 0.4612 | Dev acc: 0.7600
# Epoch 7/30 | Train loss: 0.5479 | Dev acc: 0.7600
# Epoch 8/30 | Train loss: 0.3616 | Dev acc: 0.7700
# Epoch 9/30 | Train loss: 0.4358 | Dev acc: 0.7700
# Epoch 10/30 | Train loss: 0.3130 | Dev acc: 0.7600
# Epoch 11/30 | Train loss: 0.3971 | Dev acc: 0.7700
# Epoch 12/30 | Train loss: 0.2986 | Dev acc: 0.7600
# Epoch 13/30 | Train loss: 0.2814 | Dev acc: 0.7800
# Epoch 14/30 | Train loss: 0.3473 | Dev acc: 0.7800
# Epoch 15/30 | Train loss: 0.5253 | Dev acc: 0.7500
# Epoch 16/30 | Train loss: 0.4234 | Dev acc: 0.7700
# Epoch 17/30 | Train loss: 0.7127 | Dev acc: 0.7700
# Epoch 18/30 | Train loss: 0.3525 | Dev acc: 0.7900
# Epoch 19/30 | Train loss: 0.4160 | Dev acc: 0.7800
# Epoch 20/30 | Train loss: 0.5069 | Dev acc: 0.7500
# Epoch 21/30 | Train loss: 0.4992 | Dev acc: 0.7700
# Epoch 22/30 | Train loss: 0.2519 | Dev acc: 0.7700
# Epoch 23/30 | Train loss: 0.5401 | Dev acc: 0.7700
# Epoch 24/30 | Train loss: 0.4682 | Dev acc: 0.7800
# Epoch 25/30 | Train loss: 0.3599 | Dev acc: 0.7500
# Epoch 26/30 | Train loss: 0.5135 | Dev acc: 0.7800
# Epoch 27/30 | Train loss: 0.3475 | Dev acc: 0.7900
# Epoch 28/30 | Train loss: 0.4243 | Dev acc: 0.7700
# Epoch 29/30 | Train loss: 0.3095 | Dev acc: 0.7700
# Epoch 30/30 | Train loss: 0.2529 | Dev acc: 0.7700
# Dev accuracy: 0.7800
#
# Testing configuration:
# lr=0.001, hidden=128, layers=2, dropout=0.1
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.5065 | Dev acc: 0.7500
# Epoch 2/30 | Train loss: 0.5541 | Dev acc: 0.7700
# Epoch 3/30 | Train loss: 0.3436 | Dev acc: 0.7700
# Epoch 4/30 | Train loss: 0.4640 | Dev acc: 0.7600
# Epoch 5/30 | Train loss: 0.3179 | Dev acc: 0.7800
# Epoch 6/30 | Train loss: 0.3532 | Dev acc: 0.7800
# Epoch 7/30 | Train loss: 0.3370 | Dev acc: 0.7900
# Epoch 8/30 | Train loss: 0.3700 | Dev acc: 0.7700
# Epoch 9/30 | Train loss: 0.5476 | Dev acc: 0.7200
# Epoch 10/30 | Train loss: 0.3586 | Dev acc: 0.7800
# Epoch 11/30 | Train loss: 0.3143 | Dev acc: 0.7400
# Epoch 12/30 | Train loss: 0.4444 | Dev acc: 0.7700
# Early stopping at epoch 12
# Dev accuracy: 0.7900
#
# Testing configuration:
# lr=0.001, hidden=128, layers=2, dropout=0.3
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.5046 | Dev acc: 0.7300
# Epoch 2/30 | Train loss: 0.5158 | Dev acc: 0.7100
# Epoch 3/30 | Train loss: 0.3670 | Dev acc: 0.7900
# Epoch 4/30 | Train loss: 0.6800 | Dev acc: 0.7800
# Epoch 5/30 | Train loss: 0.5656 | Dev acc: 0.7600
# Epoch 6/30 | Train loss: 0.5461 | Dev acc: 0.7700
# Epoch 7/30 | Train loss: 0.3472 | Dev acc: 0.8000
# Epoch 8/30 | Train loss: 0.5061 | Dev acc: 0.7500
# Epoch 9/30 | Train loss: 3.4038 | Dev acc: 0.7300
# Epoch 10/30 | Train loss: 0.4605 | Dev acc: 0.7600
# Epoch 11/30 | Train loss: 0.5459 | Dev acc: 0.7600
# Epoch 12/30 | Train loss: 0.5410 | Dev acc: 0.7200
# Epoch 13/30 | Train loss: 0.3853 | Dev acc: 0.7700
# Epoch 14/30 | Train loss: 0.3704 | Dev acc: 0.7800
# Epoch 15/30 | Train loss: 0.3838 | Dev acc: 0.7900
# Epoch 16/30 | Train loss: 0.3739 | Dev acc: 0.7800
# Early stopping at epoch 16
# Dev accuracy: 0.7600
#
# Testing configuration:
# lr=0.001, hidden=128, layers=4, dropout=0.1
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.4528 | Dev acc: 0.7700
# Epoch 2/30 | Train loss: 0.5227 | Dev acc: 0.7900
# Epoch 3/30 | Train loss: 0.4289 | Dev acc: 0.7800
# Epoch 4/30 | Train loss: 0.6338 | Dev acc: 0.7800
# Epoch 5/30 | Train loss: 0.4565 | Dev acc: 0.7200
# Epoch 6/30 | Train loss: 0.3854 | Dev acc: 0.7900
# Epoch 7/30 | Train loss: 0.3794 | Dev acc: 0.7600
# Epoch 8/30 | Train loss: 0.4561 | Dev acc: 0.7800
# Epoch 9/30 | Train loss: 0.3163 | Dev acc: 0.7600
# Epoch 10/30 | Train loss: 0.5813 | Dev acc: 0.7800
# Epoch 11/30 | Train loss: 0.2280 | Dev acc: 0.7700
# Epoch 12/30 | Train loss: 0.5163 | Dev acc: 0.7800
# Epoch 13/30 | Train loss: 0.3512 | Dev acc: 0.7500
# Epoch 14/30 | Train loss: 0.3938 | Dev acc: 0.7900
# Epoch 15/30 | Train loss: 0.3887 | Dev acc: 0.7900
# Epoch 16/30 | Train loss: 0.4552 | Dev acc: 0.7800
# Epoch 17/30 | Train loss: 0.2813 | Dev acc: 0.7700
# Epoch 18/30 | Train loss: 0.4669 | Dev acc: 0.7600
# Epoch 19/30 | Train loss: 0.1674 | Dev acc: 0.7900
# Epoch 20/30 | Train loss: 0.4992 | Dev acc: 0.7800
# Epoch 21/30 | Train loss: 0.3360 | Dev acc: 0.8000
# Early stopping at epoch 21
# Dev accuracy: 0.7800
#
# Testing configuration:
# lr=0.001, hidden=128, layers=4, dropout=0.3
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.6154 | Dev acc: 0.7600
# Epoch 2/30 | Train loss: 0.7347 | Dev acc: 0.7600
# Epoch 3/30 | Train loss: 0.4856 | Dev acc: 0.7900
# Epoch 4/30 | Train loss: 0.4573 | Dev acc: 0.7800
# Epoch 5/30 | Train loss: 0.4770 | Dev acc: 0.7900
# Epoch 6/30 | Train loss: 0.4131 | Dev acc: 0.8000
# Epoch 7/30 | Train loss: 0.3736 | Dev acc: 0.7600
# Epoch 8/30 | Train loss: 0.6073 | Dev acc: 0.7500
# Epoch 9/30 | Train loss: 0.2460 | Dev acc: 0.7100
# Epoch 10/30 | Train loss: 0.5250 | Dev acc: 0.7300
# Epoch 11/30 | Train loss: 0.3615 | Dev acc: 0.7700
# Epoch 12/30 | Train loss: 0.8047 | Dev acc: 0.7700
# Epoch 13/30 | Train loss: 0.3916 | Dev acc: 0.7900
# Epoch 14/30 | Train loss: 0.5109 | Dev acc: 0.7200
# Epoch 15/30 | Train loss: 0.2150 | Dev acc: 0.7800
# Epoch 16/30 | Train loss: 0.5391 | Dev acc: 0.7900
# Early stopping at epoch 16
# Dev accuracy: 0.7700
#
# Testing configuration:
# lr=0.0005, hidden=64, layers=2, dropout=0.1
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.6451 | Dev acc: 0.5200
# Epoch 2/30 | Train loss: 0.4878 | Dev acc: 0.6700
# Epoch 3/30 | Train loss: 0.5934 | Dev acc: 0.7400
# Epoch 4/30 | Train loss: 0.7244 | Dev acc: 0.7100
# Epoch 5/30 | Train loss: 0.5032 | Dev acc: 0.7800
# Epoch 6/30 | Train loss: 0.3348 | Dev acc: 0.7800
# Epoch 7/30 | Train loss: 0.5075 | Dev acc: 0.7600
# Epoch 8/30 | Train loss: 0.4904 | Dev acc: 0.7800
# Epoch 9/30 | Train loss: 0.4238 | Dev acc: 0.7700
# Epoch 10/30 | Train loss: 0.5296 | Dev acc: 0.7700
# Epoch 11/30 | Train loss: 0.3918 | Dev acc: 0.7700
# Epoch 12/30 | Train loss: 0.8556 | Dev acc: 0.7700
# Epoch 13/30 | Train loss: 0.3585 | Dev acc: 0.7700
# Epoch 14/30 | Train loss: 0.4505 | Dev acc: 0.7700
# Epoch 15/30 | Train loss: 0.3681 | Dev acc: 0.7800
# Epoch 16/30 | Train loss: 0.4266 | Dev acc: 0.7700
# Epoch 17/30 | Train loss: 0.4355 | Dev acc: 0.7800
# Epoch 18/30 | Train loss: 0.3091 | Dev acc: 0.7700
# Epoch 19/30 | Train loss: 0.5248 | Dev acc: 0.7800
# Epoch 20/30 | Train loss: 0.3348 | Dev acc: 0.7700
# Epoch 21/30 | Train loss: 0.5301 | Dev acc: 0.7900
# Epoch 22/30 | Train loss: 0.3243 | Dev acc: 0.7500
# Epoch 23/30 | Train loss: 0.3934 | Dev acc: 0.7800
# Epoch 24/30 | Train loss: 0.3269 | Dev acc: 0.7700
# Early stopping at epoch 24
# Dev accuracy: 0.7800
#
# Testing configuration:
# lr=0.0005, hidden=64, layers=2, dropout=0.3
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.6751 | Dev acc: 0.5000
# Epoch 2/30 | Train loss: 0.6166 | Dev acc: 0.6300
# Epoch 3/30 | Train loss: 0.6453 | Dev acc: 0.6600
# Epoch 4/30 | Train loss: 0.5811 | Dev acc: 0.6900
# Epoch 5/30 | Train loss: 0.5403 | Dev acc: 0.7000
# Epoch 6/30 | Train loss: 0.6069 | Dev acc: 0.7600
# Epoch 7/30 | Train loss: 0.5072 | Dev acc: 0.7800
# Epoch 8/30 | Train loss: 0.3532 | Dev acc: 0.7700
# Epoch 9/30 | Train loss: 0.4874 | Dev acc: 0.7800
# Epoch 10/30 | Train loss: 0.6926 | Dev acc: 0.7800
# Epoch 11/30 | Train loss: 0.3184 | Dev acc: 0.7600
# Epoch 12/30 | Train loss: 0.4577 | Dev acc: 0.7700
# Epoch 13/30 | Train loss: 0.5030 | Dev acc: 0.7700
# Epoch 14/30 | Train loss: 0.3266 | Dev acc: 0.7700
# Epoch 15/30 | Train loss: 0.5562 | Dev acc: 0.7500
# Epoch 16/30 | Train loss: 0.5898 | Dev acc: 0.7700
# Epoch 17/30 | Train loss: 0.4076 | Dev acc: 0.7700
# Epoch 18/30 | Train loss: 0.4477 | Dev acc: 0.7800
# Epoch 19/30 | Train loss: 0.6010 | Dev acc: 0.7700
# Epoch 20/30 | Train loss: 0.3526 | Dev acc: 0.7800
# Epoch 21/30 | Train loss: 0.3412 | Dev acc: 0.7500
# Epoch 22/30 | Train loss: 0.7253 | Dev acc: 0.7600
# Epoch 23/30 | Train loss: 0.3772 | Dev acc: 0.7700
# Epoch 24/30 | Train loss: 0.4429 | Dev acc: 0.7600
# Early stopping at epoch 24
# Dev accuracy: 0.7700
#
# Testing configuration:
# lr=0.0005, hidden=64, layers=4, dropout=0.1
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.6571 | Dev acc: 0.5000
# Epoch 2/30 | Train loss: 0.6085 | Dev acc: 0.7500
# Epoch 3/30 | Train loss: 0.6190 | Dev acc: 0.7700
# Epoch 4/30 | Train loss: 0.3513 | Dev acc: 0.8000
# Epoch 5/30 | Train loss: 0.4555 | Dev acc: 0.7700
# Epoch 6/30 | Train loss: 0.5296 | Dev acc: 0.8200
# Epoch 7/30 | Train loss: 0.5611 | Dev acc: 0.7800
# Epoch 8/30 | Train loss: 0.4515 | Dev acc: 0.7300
# Epoch 9/30 | Train loss: 0.3389 | Dev acc: 0.7500
# Epoch 10/30 | Train loss: 0.4683 | Dev acc: 0.7700
# Epoch 11/30 | Train loss: 0.4895 | Dev acc: 0.7300
# Epoch 12/30 | Train loss: 0.4466 | Dev acc: 0.7700
# Epoch 13/30 | Train loss: 0.2537 | Dev acc: 0.7800
# Epoch 14/30 | Train loss: 0.4157 | Dev acc: 0.7800
# Epoch 15/30 | Train loss: 0.5014 | Dev acc: 0.7800
# Early stopping at epoch 15
# Dev accuracy: 0.7700
#
# Testing configuration:
# lr=0.0005, hidden=64, layers=4, dropout=0.3
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.6939 | Dev acc: 0.5500
# Epoch 2/30 | Train loss: 0.6639 | Dev acc: 0.6100
# Epoch 3/30 | Train loss: 0.5792 | Dev acc: 0.7000
# Epoch 4/30 | Train loss: 0.6281 | Dev acc: 0.7100
# Epoch 5/30 | Train loss: 0.5338 | Dev acc: 0.7700
# Epoch 6/30 | Train loss: 0.4141 | Dev acc: 0.7600
# Epoch 7/30 | Train loss: 0.6120 | Dev acc: 0.7700
# Epoch 8/30 | Train loss: 0.5348 | Dev acc: 0.7800
# Epoch 9/30 | Train loss: 0.4758 | Dev acc: 0.7700
# Epoch 10/30 | Train loss: 0.4017 | Dev acc: 0.7800
# Epoch 11/30 | Train loss: 0.5788 | Dev acc: 0.7600
# Epoch 12/30 | Train loss: 0.5263 | Dev acc: 0.7800
# Epoch 13/30 | Train loss: 0.2849 | Dev acc: 0.7700
# Epoch 14/30 | Train loss: 0.5604 | Dev acc: 0.7500
# Epoch 15/30 | Train loss: 0.2638 | Dev acc: 0.7900
# Epoch 16/30 | Train loss: 0.6604 | Dev acc: 0.7800
# Epoch 17/30 | Train loss: 0.3575 | Dev acc: 0.7500
# Epoch 18/30 | Train loss: 0.4058 | Dev acc: 0.7800
# Epoch 19/30 | Train loss: 0.5280 | Dev acc: 0.7800
# Epoch 20/30 | Train loss: 0.4036 | Dev acc: 0.7600
# Epoch 21/30 | Train loss: 0.5449 | Dev acc: 0.7800
# Epoch 22/30 | Train loss: 0.3519 | Dev acc: 0.7600
# Epoch 23/30 | Train loss: 0.5069 | Dev acc: 0.7700
# Epoch 24/30 | Train loss: 0.4669 | Dev acc: 0.7700
# Epoch 25/30 | Train loss: 0.3364 | Dev acc: 0.7800
# Epoch 26/30 | Train loss: 0.4134 | Dev acc: 0.7800
# Early stopping at epoch 26
# Dev accuracy: 0.7800
#
# Testing configuration:
# lr=0.0005, hidden=128, layers=2, dropout=0.1
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.4702 | Dev acc: 0.7500
# Epoch 2/30 | Train loss: 0.6748 | Dev acc: 0.7300
# Epoch 3/30 | Train loss: 0.4434 | Dev acc: 0.7800
# Epoch 4/30 | Train loss: 0.6613 | Dev acc: 0.7800
# Epoch 5/30 | Train loss: 0.5817 | Dev acc: 0.7300
# Epoch 6/30 | Train loss: 0.5210 | Dev acc: 0.7700
# Epoch 7/30 | Train loss: 0.3906 | Dev acc: 0.7600
# Epoch 8/30 | Train loss: 0.5975 | Dev acc: 0.7500
# Epoch 9/30 | Train loss: 0.5100 | Dev acc: 0.7700
# Epoch 10/30 | Train loss: 0.3716 | Dev acc: 0.7800
# Epoch 11/30 | Train loss: 0.4600 | Dev acc: 0.7800
# Epoch 12/30 | Train loss: 0.5280 | Dev acc: 0.7700
# Epoch 13/30 | Train loss: 0.4946 | Dev acc: 0.7600
# Epoch 14/30 | Train loss: 0.3514 | Dev acc: 0.7600
# Epoch 15/30 | Train loss: 0.4276 | Dev acc: 0.7900
# Epoch 16/30 | Train loss: 0.3203 | Dev acc: 0.7900
# Early stopping at epoch 16
# Dev accuracy: 0.7800
#
# Testing configuration:
# lr=0.0005, hidden=128, layers=2, dropout=0.3
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.5656 | Dev acc: 0.7500
# Epoch 2/30 | Train loss: 0.4926 | Dev acc: 0.7300
# Epoch 3/30 | Train loss: 0.7082 | Dev acc: 0.7000
# Epoch 4/30 | Train loss: 0.5176 | Dev acc: 0.7700
# Epoch 5/30 | Train loss: 0.5221 | Dev acc: 0.7800
# Epoch 6/30 | Train loss: 0.5091 | Dev acc: 0.7800
# Epoch 7/30 | Train loss: 0.4027 | Dev acc: 0.7700
# Epoch 8/30 | Train loss: 0.4322 | Dev acc: 0.7600
# Epoch 9/30 | Train loss: 0.5097 | Dev acc: 0.7700
# Epoch 10/30 | Train loss: 0.3670 | Dev acc: 0.7700
# Epoch 11/30 | Train loss: 0.5222 | Dev acc: 0.7700
# Epoch 12/30 | Train loss: 0.4837 | Dev acc: 0.7700
# Epoch 13/30 | Train loss: 0.4363 | Dev acc: 0.7600
# Epoch 14/30 | Train loss: 0.4386 | Dev acc: 0.7700
# Epoch 15/30 | Train loss: 0.2650 | Dev acc: 0.7700
# Epoch 16/30 | Train loss: 0.3423 | Dev acc: 0.7900
# Epoch 17/30 | Train loss: 0.5131 | Dev acc: 0.7500
# Epoch 18/30 | Train loss: 0.4133 | Dev acc: 0.7500
# Epoch 19/30 | Train loss: 0.4628 | Dev acc: 0.7800
# Epoch 20/30 | Train loss: 0.3554 | Dev acc: 0.7700
# Early stopping at epoch 20
# Dev accuracy: 0.7700
#
# Testing configuration:
# lr=0.0005, hidden=128, layers=4, dropout=0.1
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.6349 | Dev acc: 0.6600
# Epoch 2/30 | Train loss: 0.5052 | Dev acc: 0.7300
# Epoch 3/30 | Train loss: 0.4862 | Dev acc: 0.7400
# Epoch 4/30 | Train loss: 0.6182 | Dev acc: 0.7600
# Epoch 5/30 | Train loss: 0.4312 | Dev acc: 0.7600
# Epoch 6/30 | Train loss: 0.3694 | Dev acc: 0.7600
# Epoch 7/30 | Train loss: 0.4289 | Dev acc: 0.7300
# Epoch 8/30 | Train loss: 0.2816 | Dev acc: 0.7700
# Epoch 9/30 | Train loss: 0.5030 | Dev acc: 0.7900
# Epoch 10/30 | Train loss: 0.2802 | Dev acc: 0.7800
# Epoch 11/30 | Train loss: 0.5352 | Dev acc: 0.7800
# Epoch 12/30 | Train loss: 0.3919 | Dev acc: 0.7300
# Epoch 13/30 | Train loss: 0.3477 | Dev acc: 0.7800
# Epoch 14/30 | Train loss: 0.4645 | Dev acc: 0.7700
# Epoch 15/30 | Train loss: 0.3374 | Dev acc: 0.7600
# Epoch 16/30 | Train loss: 0.3912 | Dev acc: 0.7300
# Early stopping at epoch 16
# Dev accuracy: 0.7800
#
# Testing configuration:
# lr=0.0005, hidden=128, layers=4, dropout=0.3
# Initialising model, optimizer, and loss function
# Starting training...
# Epoch 1/30 | Train loss: 0.6949 | Dev acc: 0.5000
# Epoch 2/30 | Train loss: 0.5824 | Dev acc: 0.6500
# Epoch 3/30 | Train loss: 0.6570 | Dev acc: 0.7700
# Epoch 4/30 | Train loss: 0.4150 | Dev acc: 0.7700
# Epoch 5/30 | Train loss: 0.4837 | Dev acc: 0.7700
# Epoch 6/30 | Train loss: 0.4521 | Dev acc: 0.7900
# Epoch 7/30 | Train loss: 0.5519 | Dev acc: 0.7700
# Epoch 8/30 | Train loss: 0.5107 | Dev acc: 0.7800
# Epoch 9/30 | Train loss: 0.3680 | Dev acc: 0.7500
# Epoch 10/30 | Train loss: 0.4264 | Dev acc: 0.7500
# Epoch 11/30 | Train loss: 0.3638 | Dev acc: 0.7600
# Epoch 12/30 | Train loss: 0.5163 | Dev acc: 0.7600
# Epoch 13/30 | Train loss: 0.4648 | Dev acc: 0.7800
# Epoch 14/30 | Train loss: 0.3282 | Dev acc: 0.7900
# Epoch 15/30 | Train loss: 0.3322 | Dev acc: 0.7800
# Epoch 16/30 | Train loss: 0.7879 | Dev acc: 0.7400
# Epoch 17/30 | Train loss: 0.2156 | Dev acc: 0.7900
# Epoch 18/30 | Train loss: 0.3823 | Dev acc: 0.7700
# Epoch 19/30 | Train loss: 0.4228 | Dev acc: 0.7700
# Epoch 20/30 | Train loss: 0.3596 | Dev acc: 0.7600
# Epoch 21/30 | Train loss: 0.5838 | Dev acc: 0.7800
# Epoch 22/30 | Train loss: 0.2485 | Dev acc: 0.7700
# Epoch 23/30 | Train loss: 0.3846 | Dev acc: 0.7700
# Early stopping at epoch 23
# Dev accuracy: 0.7700

# %%
with torch.no_grad():
    pred_nn_ling = (
        best_model_ling(X_test_ling).squeeze() > 0.5
    ).int().numpy()

results_nn_ling = evaluate_model(
    best_model_ling,
    X_test_ling,
    y_test_ling
)

print("Best parameters:")
print(best_params_ling)

print("\nTest metrics:")
print(results_nn_ling)
# Out:
# Best parameters:
# {'learning_rate': 0.001, 'hidden_size': 128, 'n_layers': 2, 'dropout': 0.1}
#
# Test metrics:
# {'Accuracy': 0.77, 'Precision': 0.7547169811320755, 'Recall': 0.8, 'F1-score': 0.7766990291262136}

# %%
# Diagnosis of the NN with linguistic features
best_model_ling.eval()

with torch.no_grad():
    y_train_pred = best_model_ling(X_train_ling)

y_train_pred = (y_train_pred > 0.5).int()

acc = accuracy_score(y_train.numpy(), y_train_pred.numpy())
print(f"Train accuracy: {acc:.4f}")
# Out:
# Train accuracy: 0.8187

# %% [markdown]
# ### Hugging face AI detector

# %%
model_path = "Oxidane/tmr-ai-text-detector"
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForSequenceClassification.from_pretrained(model_path)

# %% [markdown]
# The following code was partly provided by the creators of the model and can be found at the following adress : https://huggingface.co/Oxidane/tmr-ai-text-detector

# %%
batch_size = 16
pred_hf = []
test_texts = df.iloc[idx_test]["text"].tolist()

for i in range(0, len(test_texts), batch_size):
    batch_texts = test_texts[i:i+batch_size]

    inputs = tokenizer(
        batch_texts,
        return_tensors="pt",
        truncation=True,
        max_length=512,
        padding=True
    )

    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits
        probs = torch.softmax(logits, dim=-1)
    
    # Probability that text is AI-generated
    batch_preds = (probs[:, 1] > 0.5).int().tolist()
    # Binary classification (threshold=0.5)
    pred_hf.extend(batch_preds)

# Compute metrics
accuracy = accuracy_score(y_test.numpy(), pred_hf)
precision = precision_score(y_test.numpy(), pred_hf)
recall = recall_score(y_test.numpy(), pred_hf)
f1 = f1_score(y_test.numpy(), pred_hf)

# Store results
results_hf = {
    "Accuracy": float(accuracy),
    "Precision": float(precision),
    "Recall": float(recall),
    "F1-score": float(f1)
}

print(results_hf)
# Out:
# {'Accuracy': 0.92, 'Precision': 0.9772727272727273, 'Recall': 0.86, 'F1-score': 0.9148936170212766}

# %% [markdown]
# ## Summary results

# %%
# Global comparison table

results_df = pd.DataFrame({
    "LogReg embeddings": results_logreg,
    "LogReg embeddings + linguistic": results_logreg_ling,
    "NN embeddings": results_nn,
    "NN embeddings + linguistic": results_nn_ling,
    "Hugging Face model": results_hf
}).T

# Round values
results_df = results_df.round(4)
print(results_df)
# Out:
#                                 Accuracy  Precision  Recall  F1-score
# LogReg embeddings                   0.94     0.9400    0.94    0.9400
# LogReg embeddings + linguistic      0.94     0.9231    0.96    0.9412
# NN embeddings                       0.96     0.9423    0.98    0.9608
# NN embeddings + linguistic          0.77     0.7547    0.80    0.7767
# Hugging Face model                  0.92     0.9773    0.86    0.9149

# %% [markdown]
# ## Test significance

# %%
def mcnemar_test(y_true, pred1, pred2):

    # Correct predictions
    pred1_correct = (pred1 == y_true)
    pred2_correct = (pred2 == y_true)

    # Contingency table
    both_correct = (
        (pred1_correct == 1) &
        (pred2_correct == 1)
    ).sum()

    pred1_only = (
        (pred1_correct == 1) &
        (pred2_correct == 0)
    ).sum()

    pred2_only = (
        (pred1_correct == 0) &
        (pred2_correct == 1)
    ).sum()

    both_wrong = (
        (pred1_correct == 0) &
        (pred2_correct == 0)
    ).sum()

    table = [
        [both_correct, pred1_only],
        [pred2_only, both_wrong]
    ]

    # McNemar test
    result = mcnemar(
        table,
        exact=False,
        correction=True
    )

    return {
        "Statistic": float(result.statistic),
        "p-value": float(result.pvalue)
    }

# %%
y_true = y_test.numpy()

mcnemar_nn = mcnemar_test(
    y_true,
    pred_nn,
    pred_nn_ling
)
print("NN vs NN + linguistic")
print(mcnemar_nn)


mcnemar_logreg = mcnemar_test(
    y_true,
    pred_logreg,
    pred_logreg_ling
)
print("LogReg vs LogReg + linguistic")
print(mcnemar_logreg)

mcnemar_hf = mcnemar_test(
    y_true,
    pred_hf,
    pred_nn_ling
)
print("HF vs NN + linguistic")
print(mcnemar_hf)

mcnemar_hf_2 = mcnemar_test(
    y_true,
    pred_hf,
    pred_nn
)
print("HF vs NN")
print(mcnemar_hf_2)
# Out:
# NN vs NN + linguistic
# {'Statistic': 14.08695652173913, 'p-value': 0.00017455002670346058}
# LogReg vs LogReg + linguistic
# {'Statistic': 0.08333333333333333, 'p-value': 0.7728299926844475}
# HF vs NN + linguistic
# {'Statistic': 7.2592592592592595, 'p-value': 0.007053637888068591}
# HF vs NN
# {'Statistic': 0.9, 'p-value': 0.34278171114790873}

# %% [markdown]
# ## Visualisations

# %% [markdown]
# ### POS distrubition

# %%
# Plotting style
plt.rcParams.update({
    "font.size": 11,
    "axes.titlesize": 13,
    "axes.labelsize": 11,
    "legend.fontsize": 10
})

df_ai = df[df["label"] == 1]
df_human = df[df["label"] == 0]

# %%
fig, axes = plt.subplots(2, 5, figsize=(18, 7))
axes = axes.flatten()

for i, feature in enumerate(features):
    ax = axes[i]

    ax.hist(df_human[feature], bins=25, alpha=0.6, label="Human")
    ax.hist(df_ai[feature], bins=25, alpha=0.6, label="AI")

    ax.set_title(feature_names[feature])
    ax.set_xlabel("")
    ax.set_ylabel("")

# Une seule légende globale
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles, labels, loc="upper right")

plt.suptitle("Comparison of linguistic features: Human vs AI", fontsize=16)
plt.tight_layout()
plt.show()
